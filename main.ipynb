# %%
print("CEE6501 Final Project - DSM Solver")
# Out:
# CEE6501 Final Project - DSM Solver

# %%
import sys
sys.path.append("helpers")
sys.path.append("outputs")

from functions_main import functions_main
from helper_funcs_output import (
    print_dsm_results_3d,
    print_element_results_3d,
    plot_structure_3d,
)

# %%
# This is the section the user only needs to in the main code. Here, the user will enter a specific input as the code will display the corresponding results
# If user wants to add their own input .json file, it must be named "user_added"
# Inputs:
# example1
# example2
# structure
# case_1_study
# case_2_study
# user_added


input_file = "example_mixed_structure_3d"

results = functions_main("inputs/"+input_file+".json")

# Build path to JSON file
json_path = os.path.join(current_dir, "inputs", input_name + ".json")

# Check if user chose input correctly
if not os.path.exists(json_path):
    raise FileNotFoundError(
        f"Input file '{input_name}.json' not found. \n"
        f"Check the name and make sure it exists in the 'inputs' folder."
    )

# Open and load JSON file
with open(json_path, "r") as f:
    inputs = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 19
#      17 # Check if user chose input correctly
#      18 if not os.path.exists(json_path):
# ---> 19     raise FileNotFoundError(
#      20         f"Input file '{input_name}.json' not found. \n"
#      21         f"Check the name and make sure it exists in the 'inputs' folder."
#      22     )
#      24 # Open and load JSON file
#      25 with open(json_path, "r") as f:
#
# FileNotFoundError: Input file 'example1.json' not found.
# Check the name and make sure it exists in the 'inputs' folder.

# %%
current_dir = os.getcwd()
helpers_path = os.path.join(current_dir, "helpers")

if helpers_path not in sys.path:
    sys.path.append(helpers_path)

from functions_main import functions_main


x = functions_main(inputs)

print("Output:", x)
# Out:
# Output: 15
